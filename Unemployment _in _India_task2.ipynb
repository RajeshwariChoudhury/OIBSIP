# %% [markdown]
# # Unemployment in India Analysis

# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mlp
import seaborn as sns
import plotly.express as px
import plotly.figure_factory as ff
import plotly.graph_objects as go
# %matplotlib inline

# %%
import os

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Iris.csv',
#  'Iris_classification.html',
#  'Iris_classification_files',
#  'Iris_task1.ipynb',
#  'Unemployment in India.csv',
#  'Unemployment_Rate_upto_11_2020.csv',
#  'Untitled.ipynb']

# %% [markdown]
# # Loading Datasets

# %%
df=pd.read_csv('Unemployment in India.csv')
df_11_2020=pd.read_csv('Unemployment_Rate_upto_11_2020.csv')

# %%
df.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0           11999139.0                                     43.24  Rural
# 1           11755881.0                                     42.05  Rural
# 2           12086707.0                                     43.50  Rural
# 3           12285693.0                                     43.97  Rural
# 4           12256762.0                                     44.68  Rural

# %%
df_11_2020.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-01-2020          M                              5.48
# 1  Andhra Pradesh   29-02-2020          M                              5.83
# 2  Andhra Pradesh   31-03-2020          M                              5.79
# 3  Andhra Pradesh   30-04-2020          M                             20.51
# 4  Andhra Pradesh   31-05-2020          M                             17.43
#
#     Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 0             16635535                                     41.02    South
# 1             16545652                                     40.90    South
# 2             15881197                                     39.18    South
# 3             11336911                                     33.10    South
# 4             12988845                                     36.46    South
#
#    longitude  latitude
# 0    15.9129     79.74
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    740 non-null    object
#  1    Date                                     740 non-null    object
#  2    Frequency                                740 non-null    object
#  3    Estimated Unemployment Rate (%)          740 non-null    float64
#  4    Estimated Employed                       740 non-null    float64
#  5    Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                      740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 42.1+ KB

# %%
df_11_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 9 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    267 non-null    object
#  1    Date                                     267 non-null    object
#  2    Frequency                                267 non-null    object
#  3    Estimated Unemployment Rate (%)          267 non-null    float64
#  4    Estimated Employed                       267 non-null    int64
#  5    Estimated Labour Participation Rate (%)  267 non-null    float64
#  6   Region.1                                  267 non-null    object
#  7   longitude                                 267 non-null    float64
#  8   latitude                                  267 non-null    float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 18.9+ KB

# %%
df.shape
# Out:
# (768, 7)

# %%
df_11_2020.shape
# Out:
# (267, 9)

# %%
df.describe()
# Out:
#         Estimated Unemployment Rate (%)   Estimated Employed  \
# count                        740.000000         7.400000e+02
# mean                          11.787946         7.204460e+06
# std                           10.721298         8.087988e+06
# min                            0.000000         4.942000e+04
# 25%                            4.657500         1.190404e+06
# 50%                            8.350000         4.744178e+06
# 75%                           15.887500         1.127549e+07
# max                           76.740000         4.577751e+07
#
#         Estimated Labour Participation Rate (%)
# count                                740.000000
# mean                                  42.630122
# std                                    8.111094
# min                                   13.330000
# 25%                                   38.062500
# 50%                                   41.160000
# 75%                                   45.505000
# ...

# %%
df_11_2020.describe()
# Out:
#         Estimated Unemployment Rate (%)   Estimated Employed  \
# count                        267.000000         2.670000e+02
# mean                          12.236929         1.396211e+07
# std                           10.803283         1.336632e+07
# min                            0.500000         1.175420e+05
# 25%                            4.845000         2.838930e+06
# 50%                            9.650000         9.732417e+06
# 75%                           16.755000         2.187869e+07
# max                           75.850000         5.943376e+07
#
#         Estimated Labour Participation Rate (%)   longitude    latitude
# count                                267.000000  267.000000  267.000000
# mean                                  41.681573   22.826048   80.532425
# std                                    7.845419    6.270731    5.831738
# min                                   16.770000   10.850500   71.192400
# ...

# %%
#Checking if dataset has null values or not
df.isnull().sum()
# Out:
# Region                                      28
#  Date                                       28
#  Frequency                                  28
#  Estimated Unemployment Rate (%)            28
#  Estimated Employed                         28
#  Estimated Labour Participation Rate (%)    28
# Area                                        28
# dtype: int64

# %%
df_11_2020.isnull().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Region.1                                    0
# longitude                                   0
# latitude                                    0
# dtype: int64

# %%
#dropping null values
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Area                                        0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Area                                        0
# dtype: int64

# %%
df.shape
# Out:
# (740, 7)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df_11_2020.isna().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Region.1                                    0
# longitude                                   0
# latitude                                    0
# dtype: int64

# %%
df_11_2020.shape
# Out:
# (267, 9)

# %%
df_11_2020.duplicated().sum()
# Out:
# 0

# %%
#renaming the columns
df.columns=['State','Data','Frequency','Estimated Unemployment Rate','Estimated Employed','Estimated Labour Participation Rate','Area']

# %%
df.columns
# Out:
# Index(['State', 'Data', 'Frequency', 'Estimated Unemployment Rate',
#        'Estimated Employed', 'Estimated Labour Participation Rate', 'Area'],
#       dtype='object')

# %%
df_11_2020.columns=['State','Data','Frequency','Estimated Unemployment Rate','Estimated Employed','Estimated Labour Participation Rate','Region','Longitude','Latitude']

# %%
df_11_2020.columns
# Out:
# Index(['State', 'Data', 'Frequency', 'Estimated Unemployment Rate',
#        'Estimated Employed', 'Estimated Labour Participation Rate', 'Region',
#        'Longitude', 'Latitude'],
#       dtype='object')

# %%
df.head(3)
# Out:
#             State         Data Frequency  Estimated Unemployment Rate  \
# 0  Andhra Pradesh   31-05-2019   Monthly                         3.65
# 1  Andhra Pradesh   30-06-2019   Monthly                         3.05
# 2  Andhra Pradesh   31-07-2019   Monthly                         3.75
#
#    Estimated Employed  Estimated Labour Participation Rate   Area
# 0          11999139.0                                43.24  Rural
# 1          11755881.0                                42.05  Rural
# 2          12086707.0                                43.50  Rural

# %%
df_11_2020.head(2)
# Out:
#             State         Data Frequency  Estimated Unemployment Rate  \
# 0  Andhra Pradesh   31-01-2020         M                         5.48
# 1  Andhra Pradesh   29-02-2020         M                         5.83
#
#    Estimated Employed  Estimated Labour Participation Rate Region  Longitude  \
# 0            16635535                                41.02  South    15.9129
# 1            16545652                                40.90  South    15.9129
#
#    Latitude
# 0     79.74
# 1     79.74

# %%
#state with highest employment
df['State'].value_counts().idxmax()
# Out:
# 'Andhra Pradesh'

# %%
df['State'].value_counts()
# Out:
# Andhra Pradesh      28
# Kerala              28
# West Bengal         28
# Uttar Pradesh       28
# Tripura             28
# Telangana           28
# Tamil Nadu          28
# Rajasthan           28
# Punjab              28
# Odisha              28
# Madhya Pradesh      28
# Maharashtra         28
# Karnataka           28
# Jharkhand           28
# Himachal Pradesh    28
# Haryana             28
# Gujarat             28
# Delhi               28
# Chhattisgarh        28
# Bihar               28
# Meghalaya           27
# Uttarakhand         27
# Assam               26
# Puducherry          26
# Goa                 24
# Jammu & Kashmir     21
# Sikkim              17
# Chandigarh          12
# Name: State, dtype: int64

# %%
df_11_2020['State'].value_counts().idxmax()
# Out:
# 'Andhra Pradesh'

# %%
#state with lowset employment
df['State'].value_counts().idxmin()
# Out:
# 'Chandigarh'

# %%
df_11_2020['State'].value_counts().idxmin()
# Out:
# 'Sikkim'

# %%
#month of unemployment
import datetime as dt
import calendar

# %%
df['Data']=pd.to_datetime(df['Data'],dayfirst=True)
df['month_int']=df['Data'].dt.month
df['month']=df['month_int'].apply(lambda x: calendar.month_abbr[x])

# %%
df_11_2020['Data']=pd.to_datetime(df_11_2020['Data'],dayfirst=True)
df_11_2020['month_int']=df_11_2020['Data'].dt.month
df_11_2020['month']=df_11_2020['month_int'].apply(lambda x: calendar.month_abbr[x])

# %%
#month with highest unemployment
df['month'].value_counts().idxmax()
# Out:
# 'May'

# %%
df_11_2020['month'].value_counts().idxmax()
# Out:
# 'Mar'

# %%
#month with lowest unemployment
df['month'].value_counts().idxmin()
# Out:
# 'Apr'

# %%
df_11_2020['month'].value_counts().idxmin()
# Out:
# 'Jan'

# %%
df.head()
# Out:
#             State       Data Frequency  Estimated Unemployment Rate  \
# 0  Andhra Pradesh 2019-05-31   Monthly                         3.65
# 1  Andhra Pradesh 2019-06-30   Monthly                         3.05
# 2  Andhra Pradesh 2019-07-31   Monthly                         3.75
# 3  Andhra Pradesh 2019-08-31   Monthly                         3.32
# 4  Andhra Pradesh 2019-09-30   Monthly                         5.17
#
#    Estimated Employed  Estimated Labour Participation Rate   Area  month_int  \
# 0          11999139.0                                43.24  Rural          5
# 1          11755881.0                                42.05  Rural          6
# 2          12086707.0                                43.50  Rural          7
# 3          12285693.0                                43.97  Rural          8
# 4          12256762.0                                44.68  Rural          9
#
#   month
# 0   May
# 1   Jun
# 2   Jul
# 3   Aug
# 4   Sep

# %%
df_11_2020
# Out:
#               State       Data Frequency  Estimated Unemployment Rate  \
# 0    Andhra Pradesh 2020-01-31         M                         5.48
# 1    Andhra Pradesh 2020-02-29         M                         5.83
# 2    Andhra Pradesh 2020-03-31         M                         5.79
# 3    Andhra Pradesh 2020-04-30         M                        20.51
# 4    Andhra Pradesh 2020-05-31         M                        17.43
# ..              ...        ...       ...                          ...
# 262     West Bengal 2020-06-30         M                         7.29
# 263     West Bengal 2020-07-31         M                         6.83
# 264     West Bengal 2020-08-31         M                        14.87
# 265     West Bengal 2020-09-30         M                         9.35
# 266     West Bengal 2020-10-31         M                         9.98
#
#      Estimated Employed  Estimated Labour Participation Rate Region  \
# ...

# %%
df.drop(columns=['Frequency','month_int'])
# Out:
#               State       Data  Estimated Unemployment Rate  \
# 0    Andhra Pradesh 2019-05-31                         3.65
# 1    Andhra Pradesh 2019-06-30                         3.05
# 2    Andhra Pradesh 2019-07-31                         3.75
# 3    Andhra Pradesh 2019-08-31                         3.32
# 4    Andhra Pradesh 2019-09-30                         5.17
# ..              ...        ...                          ...
# 749     West Bengal 2020-02-29                         7.55
# 750     West Bengal 2020-03-31                         6.67
# 751     West Bengal 2020-04-30                        15.63
# 752     West Bengal 2020-05-31                        15.22
# 753     West Bengal 2020-06-30                         9.86
#
#      Estimated Employed  Estimated Labour Participation Rate   Area month
# 0            11999139.0                                43.24  Rural   May
# 1            11755881.0                                42.05  Rural   Jun
# ...

# %%
df_11_2020.drop(columns=['Frequency','month_int'])
# Out:
#               State       Data  Estimated Unemployment Rate  \
# 0    Andhra Pradesh 2020-01-31                         5.48
# 1    Andhra Pradesh 2020-02-29                         5.83
# 2    Andhra Pradesh 2020-03-31                         5.79
# 3    Andhra Pradesh 2020-04-30                        20.51
# 4    Andhra Pradesh 2020-05-31                        17.43
# ..              ...        ...                          ...
# 262     West Bengal 2020-06-30                         7.29
# 263     West Bengal 2020-07-31                         6.83
# 264     West Bengal 2020-08-31                        14.87
# 265     West Bengal 2020-09-30                         9.35
# 266     West Bengal 2020-10-31                         9.98
#
#      Estimated Employed  Estimated Labour Participation Rate Region  \
# 0              16635535                                41.02  South
# 1              16545652                                40.90  South
# ...

# %%
#top 10 states with highest unemployment
df1=df[['State','Estimated Unemployment Rate']].groupby('State').sum().sort_values('Estimated Unemployment Rate',ascending=False)

# %%
df1_11_2020=df_11_2020[['State','Estimated Unemployment Rate']].groupby('State').sum().sort_values('Estimated Unemployment Rate',ascending=False)

# %%
df1.head(15)
# Out:
#                   Estimated Unemployment Rate
# State
# Tripura                                793.81
# Haryana                                735.93
# Jharkhand                              576.38
# Bihar                                  529.71
# Himachal Pradesh                       519.13
# Delhi                                  461.87
# Rajasthan                              393.63
# Uttar Pradesh                          351.44
# Jammu & Kashmir                        339.96
# Punjab                                 336.87
# Kerala                                 283.47
# Puducherry                             265.59
# Tamil Nadu                             259.96
# Chhattisgarh                           258.73
# West Bengal                            227.49

# %%
df1_11_2020.head(8)
# Out:
#                   Estimated Unemployment Rate
# State
# Haryana                                274.77
# Tripura                                250.55
# Jharkhand                              195.39
# Bihar                                  194.71
# Delhi                                  184.14
# Puducherry                             179.42
# Himachal Pradesh                       160.65
# Rajasthan                              158.68

# %%
#visualisation of dataset

fig=plt.figure()
ax0=fig.add_subplot(1,2,1)
df1[:10].plot(kind='bar',color='yellow',figsize=(20,10),ax=ax0)
ax0.set_title('Top 10 states with highest unemployment')
ax0.set_xlabel('state')
ax0.set_ylabel('no of people unemployed')
# Out:
# Text(0, 0.5, 'no of people unemployed')

# %%
fig=plt.figure()
ax0=fig.add_subplot(1,2,1)
df1_11_2020[:10].plot(kind='bar',color='orange',figsize=(20,10),ax=ax0)
ax0.set_title('Top 10 states with highest unemployment')
ax0.set_xlabel('state')
ax0.set_ylabel('no of people unemployed')
# Out:
# Text(0, 0.5, 'no of people unemployed')

# %%
#month with highest unemployment
df2=df[['month','Estimated Unemployment Rate']].groupby('month').sum().sort_values(by='Estimated Unemployment Rate',ascending=False)
df2.head(10)
# Out:
#        Estimated Unemployment Rate
# month
# May                        1747.85
# Apr                        1205.72
# Jun                        1097.56
# Mar                         556.43
# Oct                         544.55
# Nov                         542.76
# Feb                         528.13
# Jan                         527.39
# Aug                         510.81
# Dec                         503.36

# %%
df3=df_11_2020[['month','Estimated Unemployment Rate']].groupby('month').sum().sort_values(by='Estimated Unemployment Rate',ascending=False)
df3.head(10)
# Out:
#        Estimated Unemployment Rate
# month
# May                         627.60
# Apr                         578.14
# Jun                         294.60
# Mar                         291.13
# Aug                         278.46
# Jul                         265.53
# Feb                         240.92
# Jan                         239.11
# Sep                         235.06
# Oct                         216.71

# %%
fig=plt.figure()
ax0=fig.add_subplot(1,2,1)
df2[:12].plot(kind='bar',color='green',figsize=(20,10),ax=ax0)
ax0.set_title('Month with highest unemployment')
ax0.set_xlabel('Month')
ax0.set_ylabel('Number of people unemployed')
# Out:
# Text(0, 0.5, 'Number of people unemployed')

# %%
fig=plt.figure()
ax0=fig.add_subplot(1,2,1)
df2[:12].plot(kind='bar',color='pink',figsize=(30,20),ax=ax0)
ax0.set_title('Month with highest unemployment')
ax0.set_xlabel('Month')
ax0.set_ylabel('Number of people unemployed')
# Out:
# Text(0, 0.5, 'Number of people unemployed')

# %%
#visualize labor participation rate and unemployment rate in eache month
df_EEE=df.groupby(['month'])[['Estimated Unemployment Rate','Estimated Employed','Estimated Labour Participation Rate']].mean()
df_EEE=pd.DataFrame(df_EEE).reset_index()
month=df_EEE.month
unemployment_rate=df_EEE['Estimated Unemployment Rate']
labour_participation_rate=df_EEE['Estimated Labour Participation Rate']

fig=go.Figure()

fig.add_trace(go.Bar(x=month,y=unemployment_rate,name='Unemployment_Rate'))
fig.add_trace(go.Bar(x=month,y=labour_participation_rate,name='Labour_Participation_Rate'))

fig.update_layout(title='Unemployment and labour participation rate',xaxis={'categoryorder':'array','categoryarray':['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']})
fig.show()
# Out:
# <div>                            <div id="b303b1f7-065f-45c9-96e3-0ad9eb7d2f3a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b303b1f7-065f-45c9-96e3-0ad9eb7d2f3a")) {                    Plotly.newPlot(                        "b303b1f7-065f-45c9-96e3-0ad9eb7d2f3a",                        [{"name":"Unemployment_Rate","x":["Apr","Aug","Dec","Feb","Jan","Jul","Jun","Mar","May","Nov","Oct","Sep"],"y":[23.64156862745098,9.637924528301888,9.497358490566038,9.964716981132076,9.950754716981132,9.033888888888889,10.553461538461537,10.700576923076921,16.646190476190476,9.868363636363636,9.90090909090909,9.051730769230769],"type":"bar"},{"name":"Labour_Participation_Rate","x":["Apr","Aug","Dec","Feb","Jan","Jul","Jun","Mar","May","Nov","Oct","Sep"],"y":[35.1
# ...

# %%
#visualize labor participation rate and unemployment rate in eache month
df_EEE_11_2020=df_11_2020.groupby(['month'])[['Estimated Unemployment Rate','Estimated Employed','Estimated Labour Participation Rate']].mean()
df_EEE_11_2020=pd.DataFrame(df_EEE_11_2020).reset_index()
month=df_EEE_11_2020.month
unemployment_rate=df_EEE_11_2020['Estimated Unemployment Rate']
labour_participation_rate=df_EEE_11_2020['Estimated Labour Participation Rate']

fig=go.Figure()

fig.add_trace(go.Bar(x=month,y=unemployment_rate,name='Unemployment_Rate'))
fig.add_trace(go.Bar(x=month,y=labour_participation_rate,name='Labour_Participation_Rate'))

fig.update_layout(title='Unemployment and labour participation rate',xaxis={'categoryorder':'array','categoryarray':['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']})
fig.show()
# Out:
# <div>                            <div id="602cd783-99da-49c2-b8b0-23c86e674e59" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("602cd783-99da-49c2-b8b0-23c86e674e59")) {                    Plotly.newPlot(                        "602cd783-99da-49c2-b8b0-23c86e674e59",                        [{"name":"Unemployment_Rate","x":["Apr","Aug","Feb","Jan","Jul","Jun","Mar","May","Oct","Sep"],"y":[22.236153846153847,10.313333333333333,9.266153846153847,9.196538461538463,9.834444444444443,10.911111111111111,10.782592592592593,23.244444444444444,8.026296296296296,8.705925925925927],"type":"bar"},{"name":"Labour_Participation_Rate","x":["Apr","Aug","Feb","Jan","Jul","Jun","Mar","May","Oct","Sep"],"y":[35.29730769230769,42.39074074074074,44.18076923076923,44.6265
# ...

# %%
#state-wise estimated employed
df3=df[['State','Estimated Employed']].groupby('State').sum().sort_values('Estimated Employed',ascending=False)
df3
# Out:
#                   Estimated Employed
# State
# Uttar Pradesh            786655301.0
# Maharashtra              559725484.0
# West Bengal              481559064.0
# Bihar                    346253296.0
# Tamil Nadu               343547309.0
# Gujarat                  319256358.0
# Madhya Pradesh           311233561.0
# Karnataka                298679340.0
# Rajasthan                281149813.0
# Andhra Pradesh           228314609.0
# Telangana                222310557.0
# Odisha                   183280915.0
# Assam                    139224076.0
# Punjab                   127102136.0
# Jharkhand                125138732.0
# Kerala                   123925186.0
# Chhattisgarh             120497960.0
# Haryana                   99598029.0
# Delhi                     73570360.0
# Jammu & Kashmir           37798565.0
# Uttarakhand               37536159.0
# Himachal Pradesh          29675064.0
# Tripura                   20076074.0
# Meghalaya                 18622894.0
# ...

# %%
df3=df_11_2020[['State','Estimated Employed']].groupby('State').sum().sort_values('Estimated Employed',ascending=False)
df3
# Out:
#                   Estimated Employed
# State
# Uttar Pradesh              555247990
# Maharashtra                392047582
# West Bengal                333051643
# Bihar                      236068280
# Gujarat                    227307461
# Madhya Pradesh             223183353
# Tamil Nadu                 219878981
# Karnataka                  216240176
# Rajasthan                  197317522
# Telangana                  162440825
# Andhra Pradesh             154254800
# Odisha                     127268329
# Assam                      108102755
# Punjab                      87830342
# Jharkhand                   87706424
# Kerala                      85967949
# Chhattisgarh                84213492
# Haryana                     68440590
# Delhi                       46328219
# Jammu & Kashmir             29790285
# Uttarakhand                 27432749
# Himachal Pradesh            20338849
# Tripura                     13972916
# Meghalaya                   13498153
# ...

# %%
#state-wise estimated employed visualization
df3=df[['State','Estimated Employed']].groupby('State').sum().sort_values('Estimated Employed',ascending=False)
df3.head(10)
fig=plt.figure()
ax1=fig.add_subplot(1,2,2)

#employed
df3[:10].plot(kind='bar',color='maroon',figsize=(18,9),ax=ax1)
ax1.set_title('Estimated Employed people in each state')
ax1.set_xlabel('State')
ax1.set_ylabel('No of estimated employee')
# Out:
# Text(0, 0.5, 'No of estimated employee')

# %%
#state-wise estimated employed visualization
df3=df[['State','Estimated Unemployment Rate']].groupby('State').sum().sort_values('Estimated Unemployment Rate',ascending=False)
df3.head(10)
# Out:
#                   Estimated Unemployment Rate
# State
# Tripura                                793.81
# Haryana                                735.93
# Jharkhand                              576.38
# Bihar                                  529.71
# Himachal Pradesh                       519.13
# Delhi                                  461.87
# Rajasthan                              393.63
# Uttar Pradesh                          351.44
# Jammu & Kashmir                        339.96
# Punjab                                 336.87

# %%
df3_11_2020=df_11_2020[['State','Estimated Unemployment Rate']].groupby('State').sum().sort_values('Estimated Unemployment Rate',ascending=False)
df3_11_2020.head(10)
# Out:
#                   Estimated Unemployment Rate
# State
# Haryana                                274.77
# Tripura                                250.55
# Jharkhand                              195.39
# Bihar                                  194.71
# Delhi                                  184.14
# Puducherry                             179.42
# Himachal Pradesh                       160.65
# Rajasthan                              158.68
# Jammu & Kashmir                        148.30
# Tamil Nadu                             121.87

# %%
#state-wise estimated employed visualization
df3=df[['State','Estimated Unemployment Rate']].groupby('State').sum().sort_values('Estimated Unemployment Rate',ascending=False)
df3.head(10)
fig=plt.figure()
ax1=fig.add_subplot(1,2,2)

#employed
df3[:10].plot(kind='bar',color='purple',figsize=(18,9),ax=ax1)
ax1.set_title('Estimated Unemployed people in each state')
ax1.set_xlabel('State')
ax1.set_ylabel('No of estimated unemployee')
# Out:
# Text(0, 0.5, 'No of estimated unemployee')

# %%
#state-wise estimated employed visualization
df3_11_2020=df_11_2020[['State','Estimated Unemployment Rate']].groupby('State').sum().sort_values('Estimated Unemployment Rate',ascending=False)
df3_11_2020.head(10)
fig=plt.figure()
ax1=fig.add_subplot(1,2,2)

#employed
df3_11_2020[:10].plot(kind='bar',color='crimson',figsize=(18,9),ax=ax1)
ax1.set_title('Estimated Unemployed people in each state')
ax1.set_xlabel('State')
ax1.set_ylabel('No of estimated unemployee')
# Out:
# Text(0, 0.5, 'No of estimated unemployee')

# %%
#month-wise estimated employed
df4=df[['month','Estimated Employed']].groupby('month').sum().sort_values('Estimated Employed',ascending=False)
df4.head(10)
# Out:
#        Estimated Employed
# month
# Jun           766717078.0
# May           699995530.0
# Jan           406899254.0
# Feb           403011803.0
# Sep           402452126.0
# Oct           401411032.0
# Nov           400051335.0
# Jul           399838967.0
# Aug           399610205.0
# Dec           391001555.0

# %%
df4_11_2020=df_11_2020[['month','Estimated Employed']].groupby('month').sum().sort_values('Estimated Employed',ascending=False)
df4_11_2020.head(10)
# Out:
#        Estimated Employed
# month
# Jan             406567194
# Feb             402694917
# Sep             393871643
# Oct             393659474
# Mar             392543817
# Aug             389584135
# Jul             389286580
# Jun             374149633
# May             310699661
# Apr             274825174

# %%
#month-wise estimated employed visualization
df4=df[['month','Estimated Employed']].groupby('month').sum().sort_values('Estimated Employed',ascending=False)
df4.head(10)
fig=plt.figure()
ax1=fig.add_subplot(1,2,2)

#unemployed
df4[:10].plot(kind='bar',color='lime',figsize=(18,9),ax=ax1)
ax1.set_title('Estimated Employed people in each month')
ax1.set_xlabel('month')
ax1.set_ylabel('No of estimated employee')
# Out:
# Text(0, 0.5, 'No of estimated employee')

# %%
#month-wise estimated employed visualization
df4_11_2020=df_11_2020[['month','Estimated Employed']].groupby('month').sum().sort_values('Estimated Employed',ascending=False)
df4_11_2020.head(10)
fig=plt.figure()
ax1=fig.add_subplot(1,2,2)

#employed
df4_11_2020[:10].plot(kind='bar',color='indigo',figsize=(18,9),ax=ax1)
ax1.set_title('Estimated employed people in each month')
ax1.set_xlabel('month')
ax1.set_ylabel('No of estimated employee')
# Out:
# Text(0, 0.5, 'No of estimated employee')

# %%
df4=df[['month','Estimated Unemployment Rate']].groupby('month').sum().sort_values('Estimated Unemployment Rate',ascending=False)
df4.head(10)
# Out:
#        Estimated Unemployment Rate
# month
# May                        1747.85
# Apr                        1205.72
# Jun                        1097.56
# Mar                         556.43
# Oct                         544.55
# Nov                         542.76
# Feb                         528.13
# Jan                         527.39
# Aug                         510.81
# Dec                         503.36

# %%
df4_11_2020=df_11_2020[['month','Estimated Unemployment Rate']].groupby('month').sum().sort_values('Estimated Unemployment Rate',ascending=False)
df4_11_2020.head(10)
# Out:
#        Estimated Unemployment Rate
# month
# May                         627.60
# Apr                         578.14
# Jun                         294.60
# Mar                         291.13
# Aug                         278.46
# Jul                         265.53
# Feb                         240.92
# Jan                         239.11
# Sep                         235.06
# Oct                         216.71

# %%
#month-wise estimated unemployed visualization
df4=df[['month','Estimated Unemployment Rate']].groupby('month').sum().sort_values('Estimated Unemployment Rate',ascending=False)
df4.head(10)
fig=plt.figure()
ax1=fig.add_subplot(1,2,2)

#employed
df4[:10].plot(kind='bar',color='cyan',figsize=(18,9),ax=ax1)
ax1.set_title('Estimated Unemployed people in each month')
ax1.set_xlabel('month')
ax1.set_ylabel('No of estimated unemployee')
# Out:
# Text(0, 0.5, 'No of estimated unemployee')

# %%
#month-wise estimated unemployed visualization
df4_11_2020=df_11_2020[['month','Estimated Unemployment Rate']].groupby('month').sum().sort_values('Estimated Unemployment Rate',ascending=False)
df4_11_2020.head(10)
fig=plt.figure()
ax1=fig.add_subplot(1,2,2)

#employed
df4_11_2020[:10].plot(kind='bar',color='olive',figsize=(18,9),ax=ax1)
ax1.set_title('Estimated Unemployed people in each month')
ax1.set_xlabel('month')
ax1.set_ylabel('No of estimated unemployee')
# Out:
# Text(0, 0.5, 'No of estimated unemployee')

# %%
#bar-plot unemployment rate (monthly)
fig=px.bar(df,x='State',y='Estimated Unemployment Rate',animation_frame='month',color='State',title='Unemployment Rate(state)')
fig.update_layout(xaxis={'categoryorder': 'total descending'})
fig.layout.updatemenus[0].buttons[0].args[1]['frame']['duration']=2000
fig.show()
# Out:
# <div>                            <div id="b3440dce-261b-4852-967d-e4bad9c964bd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b3440dce-261b-4852-967d-e4bad9c964bd")) {                    Plotly.newPlot(                        "b3440dce-261b-4852-967d-e4bad9c964bd",                        [{"alignmentgroup":"True","hovertemplate":"State=%{x}<br>month=May<br>Estimated Unemployment Rate=%{y}<extra></extra>","legendgroup":"Andhra Pradesh","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Andhra Pradesh","offsetgroup":"Andhra Pradesh","orientation":"v","showlegend":true,"textposition":"auto","x":["Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh"],"xaxis":"x","y":[3.65,14.46,6.09,24.91],"yaxis":"y","type":"bar"},{"alignmentgr
# ...

# %%
#Analysis of Unemployment in India dataset
